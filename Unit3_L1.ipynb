# %%
import requests

# %%
r = requests.get('http://www.citibikenyc.com/stations/json')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-cdc539c71ce5> in <module>()
# ----> 1 r = requests.get('http://www.citibikenyc.com/stations/json')
#
# NameError: name 'requests' is not defined

# %%
import requests

# %%
r = requests.get('http://www.citibikenyc.com/stations/json')

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {u'executionTime': u'2016-06-14 11:59:25 PM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2016-06-14 11:57:51 PM',
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2016-06-14 11:59:00 PM',
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
# ...

# %%
r.json().keys()
# Out:
# [u'executionTime', u'stationBeanList']

# %%
r.json()['executionTime']
# Out:
# u'2016-06-14 11:59:25 PM'

# %%
r.json()['stationBeanList']
# Out:
# [{u'altitude': u'',
#   u'availableBikes': 11,
#   u'availableDocks': 28,
#   u'city': u'',
#   u'id': 72,
#   u'landMark': u'',
#   u'lastCommunicationTime': u'2016-06-14 11:57:51 PM',
#   u'latitude': 40.76727216,
#   u'location': u'',
#   u'longitude': -73.99392888,
#   u'postalCode': u'',
#   u'stAddress1': u'W 52 St & 11 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 52 St & 11 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 6,
#   u'availableDocks': 26,
#   u'city': u'',
#   u'id': 79,
#   u'landMark': u'',
#   u'lastCommunicationTime': u'2016-06-14 11:59:00 PM',
#   u'latitude': 40.71911552,
#   u'location': u'',
#   u'longitude': -74.00666661,
#   u'postalCode': u'',
#   u'stAddress1': u'Franklin St & W Broadway',
#   u'stAddress2': u'',
#   u'stationName': u'Franklin St & W Broadway',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
# ...

# %%
len(r.json()['stationBeanList'])
# Out:
# 506

# %%
key_list = []
for station in r.json()['stationBeanList']:
    for k in station.keys():
        if k not in key_list:
            key_list.append(k)

# %%
key_list
# Out:
# [u'availableDocks',
#  u'totalDocks',
#  u'city',
#  u'altitude',
#  u'stAddress2',
#  u'longitude',
#  u'lastCommunicationTime',
#  u'postalCode',
#  u'statusValue',
#  u'testStation',
#  u'stAddress1',
#  u'stationName',
#  u'landMark',
#  u'latitude',
#  u'statusKey',
#  u'availableBikes',
#  u'id',
#  u'location']

# %%
len(key_list)
# Out:
# 18

# %%
from pandas.io.json import json_normalize
df = json_normalize(r.json()['stationBeanList'])

# %%
df
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 0                         11              28         72
# 1                          6              26         79
# 2                         14              11         82
# 3                         43              18         83
# 4                         11              27        116
# 5                          9              10        119
# 6                         19               0        120
# 7                         29               1        127
# 8                          1              25        128
# 9                          0              46        137
# 10                        16               8        143
# 11                        17               2        144
# 12                         1              37        146
# 13                         3              30        147
# 14                        29               2        150
# 15                         1              28        151
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

df['availableBikes'].hist()
plt.show()

# %%
df['totalDocks'].hist()
plt.show()

# %%
type(df['testStation'])
# Out:
# pandas.core.series.Series

# %%
for b in df['testStation']:
    if b == True:
        print df
    else:
        pass

# %%
in_service = []
not_in_service = []
status = df[['statusValue', 'stationName']]
for row in status.itertuples():
    if row[1] == "In Service":
        in_service.append(row[2])
    elif row[1] == "Not In Service":
        not_in_service.append(row[2])
    else:
        pass

# %%
len(in_service)
# Out:
# 497

# %%
len(not_in_service)
# Out:
# 9

# %%
not_in_service
# Out:
# [u'Madison St & Montgomery St',
#  u'W 13 St & 6 Ave',
#  u'E 2 St & 2 Ave',
#  u'9 Ave & W 16 St',
#  u'E 20 St & Park Ave',
#  u'Roebling St & N 4 St',
#  u'E 81 St & Park Ave',
#  u'Riverside Dr & W 82 St',
#  u'Penn Station Valet']

# %%
df['availableBikes'].mean() # mean of available bikes at all stations
# Out:
# 11.782608695652174

# %%
df['availableBikes'].median() # median of available bikes at all stations
# Out:
# 8.5

# %%
condition = (df['statusValue'] == "In Service")

# %%
df[condition]['availableBikes'].mean() # mean of available bikes at all stations in service
# Out:
# 11.979879275653923

# %%
df[condition]['availableBikes'].median() # median of available bikes at all stations in service
# Out:
# 9.0
